# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import h5py
from torch.utils.data import Dataset


class TrainDataset(Dataset):
    def __init__(self, h5_file):
        super(TrainDataset, self).__init__()
        self.h5_file = h5_file

    def __getitem__(self, idx):
        with h5py.File(self.h5_file, 'r') as f:
            lr = f['lr'][idx]
            hr = f['hr'][idx]
            return lr, hr

    def __len__(self):
        with h5py.File(self.h5_file, 'r') as f:
            return len(f['lr'])


class EvalDataset(Dataset):
    def __init__(self, h5_file):
        super(EvalDataset, self).__init__()
        self.h5_file = h5_file

    def __getitem__(self, idx):
        with h5py.File(self.h5_file, 'r') as f:
            lr = f['lr'][str(idx)].value
            hr = f['hr'][str(idx)].value
            return lr, hr

    def __len__(self):
        with h5py.File(self.h5_file, 'r') as f:
            return len(f['lr'])

# %%
from torch import nn


class ConvLayer(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size=3):
        super(ConvLayer, self).__init__()
        self.module = nn.Sequential(
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels, out_channels, kernel_size, padding=kernel_size // 2, bias=False)
        )

    def forward(self, x):
        return self.module(x)


class ResidualUnit(nn.Module):
    def __init__(self, num_features):
        super(ResidualUnit, self).__init__()
        self.module = nn.Sequential(
            ConvLayer(num_features, num_features),
            ConvLayer(num_features, num_features)
        )

    def forward(self, h0, x):
        return h0 + self.module(x)


class RecursiveBlock(nn.Module):
    def __init__(self, in_channels, out_channels, U):
        super(RecursiveBlock, self).__init__()
        self.U = U
        self.h0 = ConvLayer(in_channels, out_channels)
        self.ru = ResidualUnit(out_channels)

    def forward(self, x):
        h0 = self.h0(x)
        x = h0
        for i in range(self.U):
            x = self.ru(h0, x)
        return x


class DRRN(nn.Module):
    def __init__(self, B, U, num_channels=1, num_features=128):
        super(DRRN, self).__init__()
        self.rbs = nn.Sequential(*[RecursiveBlock(num_channels if i == 0 else num_features, num_features, U) for i in range(B)])
        self.rec = ConvLayer(num_features, num_channels)
        self._initialize_weights()

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)

    def forward(self, x):
        residual = x
        x = self.rbs(x)
        x = self.rec(x)
        x += residual
        return x

# %%
import torch
import numpy as np


def calc_patch_size(func):
    def wrapper(args):
        if args.scale == 2:
            args.patch_size = 10
        elif args.scale == 3:
            args.patch_size = 7
        elif args.scale == 4:
            args.patch_size = 6
        else:
            raise Exception('Scale Error', args.scale)
        return func(args)
    return wrapper


def convert_rgb_to_y(img, dim_order='hwc'):
    if dim_order == 'hwc':
        return 16. + (64.738 * img[..., 0] + 129.057 * img[..., 1] + 25.064 * img[..., 2]) / 256.
    else:
        return 16. + (64.738 * img[0] + 129.057 * img[1] + 25.064 * img[2]) / 256.


def convert_rgb_to_ycbcr(img, dim_order='hwc'):
    if dim_order == 'hwc':
        y = 16. + (64.738 * img[..., 0] + 129.057 * img[..., 1] + 25.064 * img[..., 2]) / 256.
        cb = 128. + (-37.945 * img[..., 0] - 74.494 * img[..., 1] + 112.439 * img[..., 2]) / 256.
        cr = 128. + (112.439 * img[..., 0] - 94.154 * img[..., 1] - 18.285 * img[..., 2]) / 256.
    else:
        y = 16. + (64.738 * img[0] + 129.057 * img[1] + 25.064 * img[2]) / 256.
        cb = 128. + (-37.945 * img[0] - 74.494 * img[1] + 112.439 * img[2]) / 256.
        cr = 128. + (112.439 * img[0] - 94.154 * img[1] - 18.285 * img[2]) / 256.
    return np.array([y, cb, cr]).transpose([1, 2, 0])


def convert_ycbcr_to_rgb(img, dim_order='hwc'):
    if dim_order == 'hwc':
        r = 298.082 * img[..., 0] / 256. + 408.583 * img[..., 2] / 256. - 222.921
        g = 298.082 * img[..., 0] / 256. - 100.291 * img[..., 1] / 256. - 208.120 * img[..., 2] / 256. + 135.576
        b = 298.082 * img[..., 0] / 256. + 516.412 * img[..., 1] / 256. - 276.836
    else:
        r = 298.082 * img[0] / 256. + 408.583 * img[2] / 256. - 222.921
        g = 298.082 * img[0] / 256. - 100.291 * img[1] / 256. - 208.120 * img[2] / 256. + 135.576
        b = 298.082 * img[0] / 256. + 516.412 * img[1] / 256. - 276.836
    return np.array([r, g, b]).transpose([1, 2, 0])


def preprocess(img, device):
    img = np.array(img).astype(np.float32)
    ycbcr = convert_rgb_to_ycbcr(img)
    x = ycbcr[..., 0]
    x /= 255.
    x = torch.from_numpy(x).to(device)
    x = x.unsqueeze(0).unsqueeze(0)
    return x, ycbcr


def calc_psnr(img1, img2):
    return 10. * torch.log10(1. / torch.mean((img1 - img2) ** 2))


from scipy.ndimage import gaussian_filter

def calc_ssim(img1, img2, sd=1.5, C1=0.01**2, C2=0.03**2):
    img1 = img1.cpu()
    img2 = img2.cpu()
    mu1 = gaussian_filter(img1, sd)
    mu2 = gaussian_filter(img2, sd)
    mu1_sq = mu1 * mu1
    mu2_sq = mu2 * mu2
    mu1_mu2 = mu1 * mu2
    sigma1_sq = gaussian_filter(img1 * img1, sd) - mu1_sq
    sigma2_sq = gaussian_filter(img2 * img2, sd) - mu2_sq
    sigma12 = gaussian_filter(img1 * img2, sd) - mu1_mu2
    
    ssim_num = ((2 * mu1_mu2 + C1) * (2 * sigma12 + C2))
    ssim_den = ((mu1_sq + mu2_sq + C1) * (sigma1_sq + sigma2_sq + C2))
    ssim_map = ssim_num / ssim_den
    mssim = np.mean(ssim_map)
    
    return mssim


class AverageMeter(object):
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %%
import os
import copy

import torch
from torch import nn
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data.dataloader import DataLoader
from tqdm import tqdm


def train(train_file, outputs_dir, eval_file, eval_scale, weights_file, B=1, U=9, num_features=128, lr=0.1, clip_grad=0.01, batch_size=128, num_epochs=50, num_workers=8, seed=123):
    outputs_dir = os.path.join(outputs_dir, 'x234')
    if not os.path.exists(outputs_dir):
        os.makedirs(outputs_dir)

    cudnn.benchmark = True
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    torch.manual_seed(seed)

    model = DRRN(B=B, U=U, num_features=num_features).to(device)

    if weights_file is not None:
        model = load_weights(model, weights_file)

    criterion = nn.MSELoss(reduction='sum')
    optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9, weight_decay=1e-4)

    train_dataset = TrainDataset(train_file)
    train_dataloader = DataLoader(dataset=train_dataset,
                                  batch_size=batch_size,
                                  shuffle=True,
                                  num_workers=num_workers,
                                  pin_memory=True)

    if eval_file is not None:
        eval_dataset = EvalDataset(eval_file)
        eval_dataloader = DataLoader(dataset=eval_dataset, batch_size=1)

    best_weights = copy.deepcopy(model.state_dict())
    best_epoch = 0
    best_psnr = 0.0

    for epoch in range(num_epochs):
        lr = lr * (0.5 ** ((epoch + 1) // 10))

        for param_group in optimizer.param_groups:
            param_group['lr'] = lr

        model.train()
        epoch_losses = AverageMeter()

        with tqdm(total=(len(train_dataset) - len(train_dataset) % batch_size), ncols=80) as t:
            t.set_description('epoch: {}/{}'.format(epoch, num_epochs - 1))

            for data in train_dataloader:
                inputs, labels = data

                inputs = inputs.to(device)
                labels = labels.to(device)

                preds = model(inputs)

                loss = criterion(preds, labels) / (2 * len(inputs))
                epoch_losses.update(loss.item(), len(inputs))

                optimizer.zero_grad()
                loss.backward()

                nn.utils.clip_grad.clip_grad_norm_(model.parameters(), clip_grad / lr)

                optimizer.step()

                t.set_postfix(loss='{:.6f}'.format(epoch_losses.avg), lr=lr)
                t.update(len(inputs))

        torch.save(model.state_dict(), os.path.join(outputs_dir, 'epoch_{}.pth'.format(epoch)))

        if eval_file is not None:
            model.eval()
            epoch_psnr = AverageMeter()

            for data in eval_dataloader:
                inputs, labels = data

                inputs = inputs.to(device)
                labels = labels.to(device)

                with torch.no_grad():
                    preds = model(inputs)

                preds = denormalize(preds.squeeze(0).squeeze(0))
                labels = denormalize(labels.squeeze(0).squeeze(0))

                epoch_psnr.update(PSNR(preds, labels, shave_border=eval_scale), len(inputs))

            print('eval psnr: {:.2f}'.format(epoch_psnr.avg))

            if epoch_psnr.avg > best_psnr:
                best_epoch = epoch
                best_psnr = epoch_psnr.avg
                best_weights = copy.deepcopy(model.state_dict())

    if eval_file is not None:
        print('best epoch: {}, psnr: {:.2f}'.format(best_epoch, best_psnr))
        torch.save(best_weights, os.path.join(outputs_dir, 'best.pth'))

# %%
import torch
import torch.backends.cudnn as cudnn
import numpy as np
import PIL.Image as pil_image


def test(weights_file, image_file, scale, save=False, debug=False, B=1, U=9, num_features=128):
    cudnn.benchmark = True
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

    model = DRRN(B=B, U=U, num_features=num_features).to(device)
    state_dict = model.state_dict()
    for n, p in torch.load(weights_file, map_location=lambda storage, loc: storage).items():
        if n in state_dict.keys():
            state_dict[n].copy_(p)
        else:
            raise KeyError(n)

    model.eval()

    image = pil_image.open(image_file).convert('RGB')
    image_file = os.path.basename(image_file)

    image_width = (image.width // scale) * scale
    image_height = (image.height // scale) * scale

    hr = image.resize((image_width, image_height), resample=pil_image.BICUBIC)
    lr = hr.resize((hr.width // scale, hr.height // scale), resample=pil_image.BICUBIC)
    bicubic = lr.resize((lr.width * scale, lr.height * scale), resample=pil_image.BICUBIC)

    lr, _ = preprocess(lr, device)
    hr, _ = preprocess(hr, device)
    bicubic, ycbcr = preprocess(bicubic, device)

    with torch.no_grad():
        # Pre upsampling
        preds = model(bicubic)

    psnr = calc_psnr(hr, preds)
    ssim = calc_ssim(hr, preds)
    if debug:
        print(f'PSNR/SSIM: {psnr:.2f}/{ssim:.4f}')

    preds = preds.mul(255.0).cpu().numpy().squeeze(0).squeeze(0)

    output = np.array([preds, ycbcr[..., 1], ycbcr[..., 2]]).transpose([1, 2, 0])
    output = np.clip(convert_ycbcr_to_rgb(output), 0.0, 255.0).astype(np.uint8)
    output = pil_image.fromarray(output)
    if save:
        save_path = f'/content/drive/Shareddrives/BTP Meets/results/Set5/{scale}x/{image_file}'
        output.save(save_path.replace('.', '_drrn.'))
    return float(psnr), float(ssim)

# %%
import os

def do_test(psnr, ssim, BASE_DIR, save=False, debug=False):
    scales = [2, 3, 4, 8, 16]

    for file in os.listdir(BASE_DIR):
        if file.endswith(".png"):
            image_file_path = os.path.join(BASE_DIR, file)
            if debug:
                print(file)
            for scale in scales:
                if debug:
                    print(f"Scale: {scale}")
                result = test(f'/content/drive/Shareddrives/BTP Meets/models/drrn.pth', image_file_path, scale, save, debug)
                if scale not in psnr:
                    psnr[scale] = []
                if scale not in ssim:
                    ssim[scale] = []
                psnr[scale].append(result[0])
                ssim[scale].append(result[1])
            if debug:
                print()

# %%
psnr = {}
ssim = {}
do_test(psnr, ssim, '/content/drive/Shareddrives/BTP Meets/datasets/test/Set5/', True, True)
# Out:
# head.png
# Scale: 2
# PSNR/SSIM: 36.01/0.8907
# Scale: 3
# PSNR/SSIM: 35.58/0.8792
# Scale: 4
# PSNR/SSIM: 32.91/0.7951
# Scale: 8
# PSNR/SSIM: 29.33/0.6819
# Scale: 16
# PSNR/SSIM: 27.02/0.6785
#
# butterfly.png
# Scale: 2
# PSNR/SSIM: 34.59/0.9752
# Scale: 3
# PSNR/SSIM: 30.58/0.9459
# Scale: 4
# PSNR/SSIM: 27.11/0.8949
# Scale: 8
# PSNR/SSIM: 17.92/0.4952
# Scale: 16
# PSNR/SSIM: 15.19/0.3714
#
# bird.png
# Scale: 2
# PSNR/SSIM: 42.37/0.9889
# Scale: 3
# PSNR/SSIM: 36.71/0.9650
# Scale: 4
# PSNR/SSIM: 33.42/0.9267
# Scale: 8
# PSNR/SSIM: 25.30/0.7026
# Scale: 16
# PSNR/SSIM: 21.75/0.5765
#
# baby.png
# Scale: 2
# PSNR/SSIM: 38.80/0.9672
# Scale: 3
# PSNR/SSIM: 36.43/0.9402
# Scale: 4
# PSNR/SSIM: 33.56/0.8918
# Scale: 8
# PSNR/SSIM: 27.42/0.7406
# Scale: 16
# PSNR/SSIM: 24.45/0.6804
#
# woman.png
# Scale: 2
# PSNR/SSIM: 36.08/0.9730
# Scale: 3
# PSNR/SSIM: 32.76/0.9433
# Scale: 4
# PSNR/SSIM: 30.01/0.9062
# Scale: 8
# PSNR/SSIM: 22.62/0.6884
# Scale: 16
# PSNR/SSIM: 19.28/0.5742

# %%
import statistics

scales = [2, 3, 4, 8, 16]
for scale in scales:
    print(f'Avg PSNR/SSIM {scale}x: {statistics.mean(psnr[scale]):.2f}/{statistics.mean(ssim[scale]):.4f}')
# Out:
# Avg PSNR/SSIM 2x: 37.57/0.9590
# Avg PSNR/SSIM 3x: 34.41/0.9347
# Avg PSNR/SSIM 4x: 31.40/0.8829
# Avg PSNR/SSIM 8x: 24.52/0.6617
# Avg PSNR/SSIM 16x: 21.54/0.5762

# %%
scales = [2, 3, 4, 8, 16]

def calc_result(dataset):
    print()
    print(dataset)
    psnr = {}
    ssim = {}
    do_test(psnr, ssim, f'/content/drive/Shareddrives/BTP Meets/datasets/test/{dataset}/', False, True)
    for scale in scales:
        print(f'Avg PSNR/SSIM {scale}x: {statistics.mean(psnr[scale]):.2f}/{statistics.mean(ssim[scale]):.4f}')

calc_result('Set14')
calc_result('BSDS100')
calc_result('Manga109')
calc_result('Urban100')

'''
Set14
Avg PSNR/SSIM 2x: 33.09/0.9147
Avg PSNR/SSIM 3x: 30.34/0.8509
Avg PSNR/SSIM 4x: 28.04/0.7740
Avg PSNR/SSIM 8x: 23.14/0.5782
Avg PSNR/SSIM 16x: 20.81/0.5050

BSDS100
Avg PSNR/SSIM 2x: 33.73/0.9226
Avg PSNR/SSIM 3x: 29.44/0.8143
Avg PSNR/SSIM 4x: 28.22/0.7552
Avg PSNR/SSIM 8x: 24.21/0.5729
Avg PSNR/SSIM 16x: 22.27/0.5148

Manga109
Avg PSNR/SSIM 2x: 37.93/0.9770
Avg PSNR/SSIM 3x: 32.620.9398
Avg PSNR/SSIM 4x: 29.51/0.8975
Avg PSNR/SSIM 8x: 21.77/0.6632
Avg PSNR/SSIM 16x: 19.44/0.6009

Urban100
Avg PSNR/SSIM 2x: 30.88/0.9158
Avg PSNR/SSIM 3x: 28.37/0.8549
Avg PSNR/SSIM 4x: 25.28/0.7574
Avg PSNR/SSIM 8x: 20.86/0.5232
Avg PSNR/SSIM 16x: 19.11/0.4598
'''
# Out:
# Manga109
# RinToSiteSippuNoNaka.png
# Scale: 2
# PSNR/SSIM: 39.16/0.9814
# Scale: 3
# PSNR/SSIM: 32.60/0.9539
# Scale: 4
# PSNR/SSIM: 29.25/0.9294
# Scale: 8
# PSNR/SSIM: 21.04/0.7699
# Scale: 16
# PSNR/SSIM: 19.16/0.7250
#
# YamatoNoHane.png
# Scale: 2
# PSNR/SSIM: 43.47/0.9928
# Scale: 3
# PSNR/SSIM: 38.62/0.9842
# Scale: 4
# PSNR/SSIM: 34.21/0.9694
# Scale: 8
# PSNR/SSIM: 24.03/0.8033
# Scale: 16
# PSNR/SSIM: 21.52/0.7527
#
# UchuKigekiM774.png
# Scale: 2
# PSNR/SSIM: 32.92/0.9407
# Scale: 3
# PSNR/SSIM: 28.00/0.8352
# Scale: 4
# PSNR/SSIM: 25.86/0.7454
# Scale: 8
# PSNR/SSIM: 20.50/0.4038
# Scale: 16
# PSNR/SSIM: 18.96/0.3450
#
# Raphael.png
# Scale: 2
# PSNR/SSIM: 37.12/0.9808
# Scale: 3
# PSNR/SSIM: 30.97/0.9369
# Scale: 4
# PSNR/SSIM: 26.67/0.8679
# Scale: 8
# PSNR/SSIM: 20.05/0.5929
# Scale: 16
# PSNR/SSIM: 17.90/0.5023
#
# YumeiroCooking.png
# Scale: 2
# PSNR/SSIM: 37.82/0.9873
# Scale: 3
# PSNR/SSIM: 30.94/0.9478
# Scale: 4
# PSNR/SSIM: 27.32/0.8814
# Scale: 8
# PSNR/SSIM: 22.43/0.6835
# Scale: 16
# PSNR/SSIM: 20.42/0.6335
#
# MayaNoAkaiKutsu.png
# Scale: 2
# PSNR/SSIM: 40.60/0.9867
# Scale: 3
# PSNR/SSIM: 35.18/0.9637
# Scale: 4
# PSNR/SSIM: 32.32/0.9362
# Scale: 8
# PSNR/SSIM: 22.86/0.7334
# Scale: 16
# PSNR/SSIM: 20.09/0.6718
#
# GarakutayaManta.png
# Scale: 2
# PSNR/SSIM: 38.34/0.9810
# Scale: 3
# PSNR/SSIM: 32.47/0.9436
# Scale: 4
# PSNR/SSIM: 29.34/0.8973
# Scale: 8
# PSNR/SSIM: 22.26/0.6650
# Scale: 16
# PSNR/SSIM: 19.86/0.6013
#
# BEMADER_P.png
# Scale: 2
# PSNR/SSIM: 34.07/0.9717
# Scale: 3
# PSNR/SSIM: 29.20/0.9275
# Scale: 4
# PSNR/SSIM: 26.81/0.8880
# Scale: 8
# PSNR/SSIM: 20.43/0.6773
# Scale: 16
# PSNR/SSIM: 17.87/0.6057
#
# RisingGirl.png
# Scale: 2
# PSNR/SSIM: 38.75/0.9826
# Scale: 3
# PSNR/SSIM: 32.61/0.9301
# Scale: 4
# PSNR/SSIM: 29.25/0.8675
# Scale: 8
# PSNR/SSIM: 21.73/0.6111
# Scale: 16
# PSNR/SSIM: 19.09/0.5287
#
# DualJustice.png
# Scale: 2
# PSNR/SSIM: 38.12/0.9887
# Scale: 3
# PSNR/SSIM: 32.30/0.9662
# Scale: 4
# PSNR/SSIM: 28.76/0.9300
# Scale: 8
# PSNR/SSIM: 20.04/0.6545
# Scale: 16
# PSNR/SSIM: 17.62/0.5794
#
# MoeruOnisan_vol19.png
# Scale: 2
# PSNR/SSIM: 39.74/0.9881
# Scale: 3
# PSNR/SSIM: 32.96/0.9627
# Scale: 4
# PSNR/SSIM: 29.52/0.9203
# Scale: 8
# PSNR/SSIM: 21.89/0.6675
# Scale: 16
# PSNR/SSIM: 19.61/0.6023
#
# Belmondo.png
# Scale: 2
# PSNR/SSIM: 36.55/0.9673
# Scale: 3
# PSNR/SSIM: 30.96/0.9298
# Scale: 4
# PSNR/SSIM: 28.20/0.8889
# Scale: 8
# PSNR/SSIM: 21.21/0.6520
# Scale: 16
# PSNR/SSIM: 19.48/0.6063
#
# SyabondamaKieta.png
# Scale: 2
# PSNR/SSIM: 35.58/0.9730
# Scale: 3
# PSNR/SSIM: 30.61/0.9197
# Scale: 4
# PSNR/SSIM: 28.02/0.8651
# Scale: 8
# PSNR/SSIM: 21.67/0.6263
# Scale: 16
# PSNR/SSIM: 19.43/0.5500
#
# MukoukizuNoChonbo.png
# Scale: 2
# PSNR/SSIM: 40.42/0.9902
# Scale: 3
# PSNR/SSIM: 35.79/0.9802
# Scale: 4
# PSNR/SSIM: 32.67/0.9686
# Scale: 8
# PSNR/SSIM: 22.23/0.8151
# Scale: 16
# PSNR/SSIM: 18.92/0.7505
#
# Arisa.png
# Scale: 2
# PSNR/SSIM: 40.81/0.9875
# Scale: 3
# PSNR/SSIM: 34.95/0.9706
# Scale: 4
# PSNR/SSIM: 31.24/0.9468
# Scale: 8
# PSNR/SSIM: 22.20/0.7169
# Scale: 16
# PSNR/SSIM: 19.55/0.6453
#
# HealingPlanet.png
# Scale: 16
# PSNR/SSIM: 18.68/0.5919
#
# MiraiSan.png
# Scale: 2
# PSNR/SSIM: 28.70/0.9319
# Scale: 3
# PSNR/SSIM: 24.28/0.8057
# Scale: 4
# PSNR/SSIM: 22.55/0.6876
# Scale: 8
# PSNR/SSIM: 19.09/0.3830
# Scale: 16
# PSNR/SSIM: 17.77/0.3298
#
# HighschoolKimengumi_vol20.png
# Scale: 2
# PSNR/SSIM: 36.30/0.9865
# Scale: 3
# PSNR/SSIM: 29.38/0.9528
# Scale: 4
# PSNR/SSIM: 25.00/0.8860
# Scale: 8
# PSNR/SSIM: 18.93/0.5805
# Scale: 16
# PSNR/SSIM: 17.42/0.5284
#
# MeteoSanStrikeDesu.png
# Scale: 2
# PSNR/SSIM: 42.61/0.9903
# Scale: 3
# PSNR/SSIM: 37.48/0.9765
# Scale: 4
# PSNR/SSIM: 33.80/0.9530
# Scale: 8
# PSNR/SSIM: 24.51/0.7711
# Scale: 16
# PSNR/SSIM: 21.08/0.6953
#
# KarappoHighschool.png
# Scale: 2
# PSNR/SSIM: 42.47/0.9905
# Scale: 3
# PSNR/SSIM: 37.35/0.9759
# Scale: 4
# PSNR/SSIM: 33.28/0.9528
# Scale: 8
# PSNR/SSIM: 25.47/0.7986
# Scale: 16
# PSNR/SSIM: 23.75/0.7688
#
# AkkeraKanjinchou.png
# Scale: 2
# PSNR/SSIM: 36.52/0.9772
# Scale: 3
# PSNR/SSIM: 30.27/0.9084
# Scale: 4
# PSNR/SSIM: 27.27/0.8256
# Scale: 8
# PSNR/SSIM: 20.36/0.5434
# Scale: 16
# PSNR/SSIM: 18.25/0.4851
#
# TsubasaNoKioku.png
# Scale: 2
# PSNR/SSIM: 39.02/0.9700
# Scale: 3
# PSNR/SSIM: 34.80/0.9227
# Scale: 4
# PSNR/SSIM: 32.55/0.8795
# Scale: 8
# PSNR/SSIM: 25.85/0.7013
# Scale: 16
# PSNR/SSIM: 22.67/0.6304
#
# ShimatteIkouze_vol01.png
# Scale: 2
# PSNR/SSIM: 39.25/0.9905
# Scale: 3
# PSNR/SSIM: 34.01/0.9747
# Scale: 4
# PSNR/SSIM: 29.67/0.9488
# Scale: 8
# PSNR/SSIM: 19.81/0.6867
# Scale: 16
# PSNR/SSIM: 17.42/0.6108
#
# KyokugenCyclone.png
# Scale: 2
# PSNR/SSIM: 29.07/0.9516
# Scale: 3
# PSNR/SSIM: 22.85/0.8216
# Scale: 4
# PSNR/SSIM: 20.69/0.7027
# Scale: 8
# PSNR/SSIM: 16.48/0.3722
# Scale: 16
# PSNR/SSIM: 15.01/0.3033
#
# Akuhamu.png
# Scale: 2
# PSNR/SSIM: 43.73/0.9879
# Scale: 3
# PSNR/SSIM: 38.66/0.9689
# Scale: 4
# PSNR/SSIM: 35.65/0.9480
# Scale: 8
# PSNR/SSIM: 26.38/0.7989
# Scale: 16
# PSNR/SSIM: 22.37/0.7237
#
# TapkunNoTanteisitsu.png
# Scale: 2
# PSNR/SSIM: 40.98/0.9891
# Scale: 3
# PSNR/SSIM: 35.45/0.9729
# Scale: 4
# PSNR/SSIM: 32.05/0.9537
# Scale: 8
# PSNR/SSIM: 23.24/0.7845
# Scale: 16
# PSNR/SSIM: 20.58/0.7379
#
# Saisoku.png
# Scale: 2
# PSNR/SSIM: 33.96/0.9383
# Scale: 3
# PSNR/SSIM: 29.45/0.8469
# Scale: 4
# PSNR/SSIM: 27.40/0.8193
# Scale: 8
# PSNR/SSIM: 19.35/0.5684
# Scale: 16
# PSNR/SSIM: 16.88/0.4761
#
# PikaruGenkiDesu.png
# Scale: 2
# PSNR/SSIM: 36.36/0.9835
# Scale: 3
# PSNR/SSIM: 30.84/0.9513
# Scale: 4
# PSNR/SSIM: 27.54/0.9035
# Scale: 8
# PSNR/SSIM: 20.52/0.6143
# Scale: 16
# PSNR/SSIM: 18.81/0.5613
#
# TouyouKidan.png
# Scale: 2
# PSNR/SSIM: 36.75/0.9746
# Scale: 3
# PSNR/SSIM: 31.71/0.9365
# Scale: 4
# PSNR/SSIM: 28.17/0.8954
# Scale: 8
# PSNR/SSIM: 20.07/0.6542
# Scale: 16
# PSNR/SSIM: 18.21/0.6009
#
# MAD_STONE.png
# Scale: 2
# PSNR/SSIM: 41.50/0.9877
# Scale: 3
# PSNR/SSIM: 36.44/0.9684
# Scale: 4
# PSNR/SSIM: 33.59/0.9428
# Scale: 8
# PSNR/SSIM: 26.21/0.7705
# Scale: 16
# PSNR/SSIM: 23.80/0.7257
#
# GinNoChimera.png
# Scale: 2
# PSNR/SSIM: 42.19/0.9906
# Scale: 3
# PSNR/SSIM: 38.37/0.9795
# Scale: 4
# PSNR/SSIM: 34.86/0.9675
# Scale: 8
# PSNR/SSIM: 24.35/0.8295
# Scale: 16
# PSNR/SSIM: 22.02/0.7919
#
# YukiNoFuruMachi.png
# Scale: 2
# PSNR/SSIM: 43.28/0.9827
# Scale: 3
# PSNR/SSIM: 38.95/0.9595
# Scale: 4
# PSNR/SSIM: 36.07/0.9397
# Scale: 8
# PSNR/SSIM: 26.54/0.7963
# Scale: 16
# PSNR/SSIM: 23.66/0.7466
#
# ByebyeC-BOY.png
# Scale: 2
# PSNR/SSIM: 40.83/0.9910
# Scale: 3
# PSNR/SSIM: 36.06/0.9776
# Scale: 4
# PSNR/SSIM: 32.06/0.9509
# Scale: 8
# PSNR/SSIM: 22.06/0.7604
# Scale: 16
# PSNR/SSIM: 20.05/0.7157
#
# UltraEleven.png
# Scale: 2
# PSNR/SSIM: 31.38/0.9728
# Scale: 3
# PSNR/SSIM: 25.58/0.9216
# Scale: 4
# PSNR/SSIM: 22.77/0.8576
# Scale: 8
# PSNR/SSIM: 17.00/0.5241
# Scale: 16
# PSNR/SSIM: 15.38/0.4555
#
# HighschoolKimengumi_vol01.png
# Scale: 2
# PSNR/SSIM: 35.06/0.9873
# Scale: 3
# PSNR/SSIM: 28.72/0.9587
# Scale: 4
# PSNR/SSIM: 24.64/0.9031
# Scale: 8
# PSNR/SSIM: 17.41/0.5352
# Scale: 16
# PSNR/SSIM: 15.80/0.4747
#
# Hamlet.png
# Scale: 2
# PSNR/SSIM: 37.08/0.9895
# Scale: 3
# PSNR/SSIM: 31.96/0.9734
# Scale: 4
# PSNR/SSIM: 28.76/0.9535
# Scale: 8
# PSNR/SSIM: 18.63/0.6989
# Scale: 16
# PSNR/SSIM: 15.32/0.5962
#
# LancelotFullThrottle.png
# Scale: 2
# PSNR/SSIM: 42.75/0.9953
# Scale: 3
# PSNR/SSIM: 36.81/0.9846
# Scale: 4
# PSNR/SSIM: 33.59/0.9681
# Scale: 8
# PSNR/SSIM: 23.74/0.7945
# Scale: 16
# PSNR/SSIM: 20.19/0.7249
#
# ToutaMairimasu.png
# Scale: 2
# PSNR/SSIM: 33.50/0.9709
# Scale: 3
# PSNR/SSIM: 28.70/0.9243
# Scale: 4
# PSNR/SSIM: 25.52/0.8624
# Scale: 8
# PSNR/SSIM: 18.53/0.5297
# Scale: 16
# PSNR/SSIM: 16.39/0.4334
#
# MemorySeijin.png
# Scale: 2
# PSNR/SSIM: 42.70/0.9715
# Scale: 3
# PSNR/SSIM: 38.36/0.9341
# Scale: 4
# PSNR/SSIM: 36.55/0.9100
# Scale: 8
# PSNR/SSIM: 30.94/0.8207
# Scale: 16
# PSNR/SSIM: 27.96/0.7828
#
# MariaSamaNihaNaisyo.png
# Scale: 2
# PSNR/SSIM: 38.10/0.9850
# Scale: 3
# PSNR/SSIM: 32.42/0.9625
# Scale: 4
# PSNR/SSIM: 29.07/0.9365
# Scale: 8
# PSNR/SSIM: 21.52/0.7502
# Scale: 16
# PSNR/SSIM: 19.53/0.7166
#
# TotteokiNoABC.png
# Scale: 2
# PSNR/SSIM: 41.65/0.9897
# Scale: 3
# PSNR/SSIM: 36.04/0.9696
# Scale: 4
# PSNR/SSIM: 33.19/0.9491
# Scale: 8
# PSNR/SSIM: 23.22/0.7667
# Scale: 16
# PSNR/SSIM: 20.94/0.7164
#
# SonokiDeABC.png
# Scale: 2
# PSNR/SSIM: 40.34/0.9854
# Scale: 3
# PSNR/SSIM: 34.74/0.9575
# Scale: 4
# PSNR/SSIM: 30.99/0.9174
# Scale: 8
# PSNR/SSIM: 23.19/0.6706
# Scale: 16
# PSNR/SSIM: 21.31/0.6130
#
# Donburakokko.png
# Scale: 2
# PSNR/SSIM: 36.28/0.9826
# Scale: 3
# PSNR/SSIM: 30.07/0.9427
# Scale: 4
# PSNR/SSIM: 26.45/0.8848
# Scale: 8
# PSNR/SSIM: 20.38/0.5932
# Scale: 16
# PSNR/SSIM: 18.98/0.5333
#
# EverydayOsakanaChan.png
# Scale: 2
# PSNR/SSIM: 41.55/0.9947
# Scale: 3
# PSNR/SSIM: 35.35/0.9842
# Scale: 4
# PSNR/SSIM: 31.34/0.9668
# Scale: 8
# PSNR/SSIM: 22.69/0.8237
# Scale: 16
# PSNR/SSIM: 20.21/0.7833
#
# MomoyamaHaikagura.png
# Scale: 2
# PSNR/SSIM: 29.31/0.9206
# Scale: 3
# PSNR/SSIM: 25.82/0.8360
# Scale: 4
# PSNR/SSIM: 24.02/0.7450
# Scale: 8
# PSNR/SSIM: 20.79/0.5209
# Scale: 16
# PSNR/SSIM: 19.57/0.4740
#
# OhWareraRettouSeitokai.png
# Scale: 2
# PSNR/SSIM: 40.24/0.9883
# Scale: 3
# PSNR/SSIM: 34.79/0.9646
# Scale: 4
# PSNR/SSIM: 31.53/0.9342
# Scale: 8
# PSNR/SSIM: 22.02/0.7108
# Scale: 16
# PSNR/SSIM: 19.83/0.6644
#
# SaladDays_vol01.png
# Scale: 2
# PSNR/SSIM: 39.07/0.9877
# Scale: 3
# PSNR/SSIM: 33.12/0.9574
# Scale: 4
# PSNR/SSIM: 30.12/0.9192
# Scale: 8
# PSNR/SSIM: 23.08/0.7191
# Scale: 16
# PSNR/SSIM: 20.48/0.6597
#
# HeiseiJimen.png
# Scale: 2
# PSNR/SSIM: 39.52/0.9865
# Scale: 3
# PSNR/SSIM: 33.76/0.9628
# Scale: 4
# PSNR/SSIM: 30.35/0.9320
# Scale: 8
# PSNR/SSIM: 23.61/0.7401
# Scale: 16
# PSNR/SSIM: 21.30/0.6820
#
# TaiyouNiSmash.png
# Scale: 2
# PSNR/SSIM: 42.48/0.9881
# Scale: 3
# PSNR/SSIM: 37.66/0.9694
# Scale: 4
# PSNR/SSIM: 34.41/0.9469
# Scale: 8
# PSNR/SSIM: 25.16/0.7733
# Scale: 16
# PSNR/SSIM: 22.48/0.7233
#
# HarukaRefrain.png
# Scale: 2
# PSNR/SSIM: 38.40/0.9822
# Scale: 3
# PSNR/SSIM: 33.57/0.9547
# Scale: 4
# PSNR/SSIM: 31.14/0.9281
# Scale: 8
# PSNR/SSIM: 23.88/0.7670
# Scale: 16
# PSNR/SSIM: 21.38/0.7168
#
# PrayerHaNemurenai.png
# Scale: 2
# PSNR/SSIM: 31.84/0.8606
# Scale: 3
# PSNR/SSIM: 30.33/0.8016
# Scale: 4
# PSNR/SSIM: 27.85/0.7176
# Scale: 8
# PSNR/SSIM: 24.02/0.5443
# Scale: 16
# PSNR/SSIM: 22.33/0.4982
#
# HisokaReturns.png
# Scale: 2
# PSNR/SSIM: 34.61/0.9250
# Scale: 3
# PSNR/SSIM: 30.21/0.8171
# Scale: 4
# PSNR/SSIM: 28.10/0.7461
# Scale: 8
# PSNR/SSIM: 21.97/0.5146
# Scale: 16
# PSNR/SSIM: 20.04/0.4663
#
# Count3DeKimeteAgeru.png
# Scale: 2
# PSNR/SSIM: 38.16/0.9682
# Scale: 3
# PSNR/SSIM: 33.69/0.9291
# Scale: 4
# PSNR/SSIM: 30.60/0.8984
# Scale: 8
# PSNR/SSIM: 21.49/0.6870
# Scale: 16
# PSNR/SSIM: 18.84/0.6259
#
# KoukouNoHitotachi.png
# Scale: 2
# PSNR/SSIM: 37.84/0.9685
# Scale: 3
# PSNR/SSIM: 31.76/0.8958
# Scale: 4
# PSNR/SSIM: 29.52/0.8382
# Scale: 8
# PSNR/SSIM: 22.11/0.5618
# Scale: 16
# PSNR/SSIM: 19.81/0.5041
#
# MadouTaiga.png
# Scale: 2
# PSNR/SSIM: 34.48/0.9628
# Scale: 3
# PSNR/SSIM: 29.50/0.9115
# Scale: 4
# PSNR/SSIM: 26.12/0.8513
# Scale: 8
# PSNR/SSIM: 20.39/0.6200
# Scale: 16
# PSNR/SSIM: 18.51/0.5613
#
# Jyovolley.png
# Scale: 2
# PSNR/SSIM: 41.58/0.9920
# Scale: 3
# PSNR/SSIM: 37.14/0.9812
# Scale: 4
# PSNR/SSIM: 33.88/0.9655
# Scale: 8
# PSNR/SSIM: 21.55/0.7400
# Scale: 16
# PSNR/SSIM: 17.90/0.6448
#
# Ningyoushi.png
# Scale: 2
# PSNR/SSIM: 40.64/0.9807
# Scale: 3
# PSNR/SSIM: 36.29/0.9532
# Scale: 4
# PSNR/SSIM: 33.15/0.9237
# Scale: 8
# PSNR/SSIM: 25.04/0.7605
# Scale: 16
# PSNR/SSIM: 22.50/0.7208
#
# Joouari.png
# Scale: 2
# PSNR/SSIM: 33.40/0.9423
# Scale: 3
# PSNR/SSIM: 29.17/0.8930
# Scale: 4
# PSNR/SSIM: 27.36/0.8555
# Scale: 8
# PSNR/SSIM: 21.13/0.6116
# Scale: 16
# PSNR/SSIM: 18.77/0.5292
#
# YumeNoKayoiji.png
# Scale: 2
# PSNR/SSIM: 38.79/0.9689
# Scale: 3
# PSNR/SSIM: 33.85/0.9121
# Scale: 4
# PSNR/SSIM: 31.35/0.8556
# Scale: 8
# PSNR/SSIM: 24.24/0.6351
# Scale: 16
# PSNR/SSIM: 21.24/0.5673
#
# ARMS.png
# Scale: 2
# PSNR/SSIM: 36.00/0.9538
# Scale: 3
# PSNR/SSIM: 30.77/0.8803
# Scale: 4
# PSNR/SSIM: 28.19/0.8113
# Scale: 8
# PSNR/SSIM: 23.62/0.6084
# Scale: 16
# PSNR/SSIM: 22.05/0.5651
#
# TensiNoHaneToAkumaNoShippo.png
# Scale: 2
# PSNR/SSIM: 37.12/0.9834
# Scale: 3
# PSNR/SSIM: 30.77/0.9417
# Scale: 4
# PSNR/SSIM: 27.51/0.8811
# Scale: 8
# PSNR/SSIM: 20.82/0.5935
# Scale: 16
# PSNR/SSIM: 18.28/0.5073
#
# BakuretsuKungFuGirl.png
# Scale: 2
# PSNR/SSIM: 38.58/0.9850
# Scale: 3
# PSNR/SSIM: 33.01/0.9553
# Scale: 4
# PSNR/SSIM: 29.84/0.9154
# Scale: 8
# PSNR/SSIM: 20.98/0.6155
# Scale: 16
# PSNR/SSIM: 18.94/0.5610
#
# YoumaKourin.png
# Scale: 2
# PSNR/SSIM: 36.50/0.9733
# Scale: 3
# PSNR/SSIM: 31.45/0.9236
# Scale: 4
# PSNR/SSIM: 28.51/0.8686
# Scale: 8
# PSNR/SSIM: 22.00/0.6054
# Scale: 16
# PSNR/SSIM: 19.70/0.5345
#
# KimiHaBokuNoTaiyouDa.png
# Scale: 2
# PSNR/SSIM: 35.62/0.9749
# Scale: 3
# PSNR/SSIM: 30.22/0.9342
# Scale: 4
# PSNR/SSIM: 26.86/0.8673
# Scale: 8
# PSNR/SSIM: 20.06/0.5231
# Scale: 16
# PSNR/SSIM: 17.83/0.4542
#
# UnbalanceTokyo.png
# Scale: 16
# PSNR/SSIM: 18.14/0.5927
#
# DollGun.png
# Scale: 2
# PSNR/SSIM: 37.62/0.9827
# Scale: 3
# PSNR/SSIM: 31.88/0.9507
# Scale: 4
# PSNR/SSIM: 27.98/0.9020
# Scale: 8
# PSNR/SSIM: 20.58/0.6054
# Scale: 16
# PSNR/SSIM: 18.09/0.5185
#
# YasasiiAkuma.png
# Scale: 2
# PSNR/SSIM: 37.80/0.9795
# Scale: 3
# PSNR/SSIM: 31.92/0.9417
# Scale: 4
# PSNR/SSIM: 28.14/0.8963
# Scale: 8
# PSNR/SSIM: 21.33/0.6851
# Scale: 16
# PSNR/SSIM: 19.01/0.6291
#
# WarewareHaOniDearu.png
# Scale: 2
# PSNR/SSIM: 34.50/0.9832
# Scale: 3
# PSNR/SSIM: 26.70/0.9322
# Scale: 4
# PSNR/SSIM: 23.48/0.8280
# Scale: 8
# PSNR/SSIM: 17.76/0.3111
# Scale: 16
# PSNR/SSIM: 17.04/0.2813
#
# GakuenNoise.png
# Scale: 2
# PSNR/SSIM: 39.00/0.9838
# Scale: 3
# PSNR/SSIM: 33.91/0.9583
# Scale: 4
# PSNR/SSIM: 30.58/0.9194
# Scale: 8
# PSNR/SSIM: 20.40/0.6118
# Scale: 16
# PSNR/SSIM: 17.14/0.5099
#
# ParaisoRoad.png
# Scale: 2
# PSNR/SSIM: 39.41/0.9856
# Scale: 3
# PSNR/SSIM: 33.55/0.9593
# Scale: 4
# PSNR/SSIM: 30.01/0.9206
# Scale: 8
# PSNR/SSIM: 22.02/0.6752
# Scale: 16
# PSNR/SSIM: 19.82/0.6219
#
# PrismHeart.png
# Scale: 2
# PSNR/SSIM: 42.07/0.9907
# Scale: 3
# PSNR/SSIM: 36.71/0.9745
# Scale: 4
# PSNR/SSIM: 33.79/0.9542
# Scale: 8
# PSNR/SSIM: 24.04/0.7903
# Scale: 16
# PSNR/SSIM: 20.90/0.7285
#
# UchiNoNyansDiary_000.png
# Scale: 2
# PSNR/SSIM: 36.98/0.9914
# Scale: 3
# PSNR/SSIM: 31.28/0.9766
# Scale: 4
# PSNR/SSIM: 28.09/0.9539
# Scale: 8
# PSNR/SSIM: 18.96/0.7314
# Scale: 16
# PSNR/SSIM: 16.71/0.6874
#
# MoeruOnisan_vol01.png
# Scale: 2
# PSNR/SSIM: 37.45/0.9847
# Scale: 3
# PSNR/SSIM: 31.54/0.9635
# Scale: 4
# PSNR/SSIM: 28.69/0.9390
# Scale: 8
# PSNR/SSIM: 20.00/0.6800
# Scale: 16
# PSNR/SSIM: 18.33/0.6257
#
# MagicStarGakuin.png
# Scale: 2
# PSNR/SSIM: 37.02/0.9837
# Scale: 3
# PSNR/SSIM: 30.84/0.9463
# Scale: 4
# PSNR/SSIM: 27.44/0.8904
# Scale: 8
# PSNR/SSIM: 20.91/0.6012
# Scale: 16
# PSNR/SSIM: 18.77/0.5187
#
# TetsuSan.png
# Scale: 2
# PSNR/SSIM: 34.59/0.9892
# Scale: 3
# PSNR/SSIM: 28.94/0.9620
# Scale: 4
# PSNR/SSIM: 26.08/0.9387
# Scale: 8
# PSNR/SSIM: 17.69/0.7133
# Scale: 16
# PSNR/SSIM: 15.56/0.6464
#
# SeisinkiVulnus.png
# Scale: 2
# PSNR/SSIM: 39.09/0.9790
# Scale: 3
# PSNR/SSIM: 33.96/0.9386
# Scale: 4
# PSNR/SSIM: 30.77/0.8911
# Scale: 8
# PSNR/SSIM: 23.55/0.6529
# Scale: 16
# PSNR/SSIM: 21.50/0.5996
#
# ReveryEarth.png
# Scale: 2
# PSNR/SSIM: 37.05/0.9777
# Scale: 3
# PSNR/SSIM: 31.70/0.9359
# Scale: 4
# PSNR/SSIM: 28.98/0.8877
# Scale: 8
# PSNR/SSIM: 22.15/0.6357
# Scale: 16
# PSNR/SSIM: 19.58/0.5653
#
# TasogareTsushin.png
# Scale: 2
# PSNR/SSIM: 37.36/0.9791
# Scale: 3
# PSNR/SSIM: 31.87/0.9429
# Scale: 4
# PSNR/SSIM: 29.37/0.9094
# Scale: 8
# PSNR/SSIM: 21.72/0.7198
# Scale: 16
# PSNR/SSIM: 18.86/0.6539
#
# AosugiruHaru.png
# Scale: 2
# PSNR/SSIM: 46.75/0.9940
# Scale: 3
# PSNR/SSIM: 42.60/0.9883
# Scale: 4
# PSNR/SSIM: 39.48/0.9790
# Scale: 8
# PSNR/SSIM: 27.04/0.8508
# Scale: 16
# PSNR/SSIM: 24.35/0.8116
#
# JijiBabaFight.png
# Scale: 2
# PSNR/SSIM: 39.04/0.9799
# Scale: 3
# PSNR/SSIM: 34.01/0.9449
# Scale: 4
# PSNR/SSIM: 30.57/0.9033
# Scale: 8
# PSNR/SSIM: 21.68/0.6546
# Scale: 16
# PSNR/SSIM: 19.26/0.5797
#
# OL_Lunch.png
# Scale: 2
# PSNR/SSIM: 33.59/0.9860
# Scale: 3
# PSNR/SSIM: 27.60/0.9555
# Scale: 4
# PSNR/SSIM: 24.67/0.9092
# Scale: 8
# PSNR/SSIM: 19.58/0.7009
# Scale: 16
# PSNR/SSIM: 17.77/0.6595
#
# BokuHaSitatakaKun.png
# Scale: 2
# PSNR/SSIM: 38.08/0.9886
# Scale: 3
# PSNR/SSIM: 31.72/0.9685
# Scale: 4
# PSNR/SSIM: 27.40/0.9307
# Scale: 8
# PSNR/SSIM: 19.72/0.6536
# Scale: 16
# PSNR/SSIM: 18.07/0.5991
#
# MagicianLoad.png
# Scale: 2
# PSNR/SSIM: 33.29/0.9086
# Scale: 3
# PSNR/SSIM: 28.70/0.8246
# Scale: 4
# PSNR/SSIM: 26.64/0.7688
# Scale: 8
# PSNR/SSIM: 22.15/0.5499
# Scale: 16
# PSNR/SSIM: 20.40/0.4949
#
# JangiriPonpon.png
# Scale: 2
# PSNR/SSIM: 33.70/0.9719
# Scale: 3
# PSNR/SSIM: 28.72/0.9177
# Scale: 4
# PSNR/SSIM: 25.90/0.8592
# Scale: 8
# PSNR/SSIM: 19.02/0.5508
# Scale: 16
# PSNR/SSIM: 16.77/0.4734
#
# ShimatteIkouze_vol26.png
# Scale: 2
# PSNR/SSIM: 35.96/0.9876
# Scale: 3
# PSNR/SSIM: 29.88/0.9642
# Scale: 4
# PSNR/SSIM: 26.14/0.9304
# Scale: 8
# PSNR/SSIM: 17.92/0.6517
# Scale: 16
# PSNR/SSIM: 15.89/0.5804
#
# SamayoeruSyonenNiJunaiWo.png
# Scale: 2
# PSNR/SSIM: 37.46/0.9707
# Scale: 3
# PSNR/SSIM: 32.05/0.9154
# Scale: 4
# PSNR/SSIM: 28.88/0.8548
# Scale: 8
# PSNR/SSIM: 21.59/0.5634
# Scale: 16
# PSNR/SSIM: 19.19/0.4905
#
# LoveHina_vol14.png
# Scale: 2
# PSNR/SSIM: 36.03/0.9801
# Scale: 3
# PSNR/SSIM: 30.10/0.9384
# Scale: 4
# PSNR/SSIM: 26.69/0.8738
# Scale: 8
# PSNR/SSIM: 20.86/0.6034
# Scale: 16
# PSNR/SSIM: 18.69/0.5279
#
# ThatsIzumiko_000.png
# Scale: 2
# PSNR/SSIM: 26.95/0.9281
# Scale: 3
# PSNR/SSIM: 22.30/0.7956
# Scale: 4
# PSNR/SSIM: 20.68/0.6977
# Scale: 8
# PSNR/SSIM: 16.25/0.3451
# Scale: 16
# PSNR/SSIM: 14.80/0.2799
#
# MisutenaideDaisy.png
# Scale: 2
# PSNR/SSIM: 41.54/0.9915
# Scale: 3
# PSNR/SSIM: 35.25/0.9772
# Scale: 4
# PSNR/SSIM: 32.44/0.9622
# Scale: 8
# PSNR/SSIM: 22.81/0.7855
# Scale: 16
# PSNR/SSIM: 20.00/0.7290
#
# HinagikuKenzan.png
# Scale: 2
# PSNR/SSIM: 39.95/0.9778
# Scale: 3
# PSNR/SSIM: 34.74/0.9342
# Scale: 4
# PSNR/SSIM: 31.71/0.8806
# Scale: 8
# PSNR/SSIM: 24.61/0.6747
# Scale: 16
# PSNR/SSIM: 21.69/0.6191
#
# YouchienBoueigumi.png
# Scale: 2
# PSNR/SSIM: 39.58/0.9905
# Scale: 3
# PSNR/SSIM: 35.38/0.9844
# Scale: 4
# PSNR/SSIM: 29.94/0.9665
# Scale: 8
# PSNR/SSIM: 20.12/0.7057
# Scale: 16
# PSNR/SSIM: 17.40/0.6554
#
# Avg PSNR/SSIM 2x: 37.93/0.9770
# Avg PSNR/SSIM 3x: 32.62/0.9398
# Avg PSNR/SSIM 4x: 29.51/0.8975
# Avg PSNR/SSIM 8x: 21.77/0.6632
# Avg PSNR/SSIM 16x: 19.44/0.6009
#
# Urban100
# img_001.png
# Scale: 2
# PSNR/SSIM: 32.12/0.9008
# Scale: 3
# PSNR/SSIM: 29.87/0.8522
# Scale: 4
# PSNR/SSIM: 27.09/0.7549
# Scale: 8
# PSNR/SSIM: 23.09/0.5698
# Scale: 16
# PSNR/SSIM: 20.87/0.4998
#
# img_071.png
# Scale: 2
# PSNR/SSIM: 31.63/0.8475
# Scale: 3
# PSNR/SSIM: 29.14/0.7408
# Scale: 4
# PSNR/SSIM: 27.42/0.6423
# Scale: 8
# PSNR/SSIM: 24.18/0.4555
# Scale: 16
# PSNR/SSIM: 23.11/0.4270
#
# Scale: 3
# PSNR/SSIM: 23.75/0.8755
# Scale: 4
# PSNR/SSIM: 20.95/0.7566
# Scale: 8
# PSNR/SSIM: 18.17/0.5056
# Scale: 16
# PSNR/SSIM: 17.20/0.4556
#
# img_024.png
# Scale: 2
# PSNR/SSIM: 25.41/0.8688
# Scale: 3
# PSNR/SSIM: 22.80/0.7618
# Scale: 4
# PSNR/SSIM: 19.56/0.6121
# Scale: 8
# PSNR/SSIM: 16.32/0.2957
# Scale: 16
# PSNR/SSIM: 15.10/0.2353
#
# img_073.png
# Scale: 2
# PSNR/SSIM: 25.48/0.8579
# Scale: 3
# PSNR/SSIM: 23.33/0.7321
# Scale: 4
# PSNR/SSIM: 20.04/0.5305
# Scale: 8
# PSNR/SSIM: 18.17/0.2467
# Scale: 16
# PSNR/SSIM: 17.14/0.1771
#
# img_003.png
# Scale: 2
# PSNR/SSIM: 27.70/0.8727
# Scale: 3
# PSNR/SSIM: 26.34/0.7968
# Scale: 4
# PSNR/SSIM: 23.40/0.6546
# Scale: 8
# PSNR/SSIM: 20.28/0.4102
# Scale: 16
# PSNR/SSIM: 18.94/0.3559
#
# img_042.png
# Scale: 2
# PSNR/SSIM: 35.67/0.9720
# Scale: 3
# PSNR/SSIM: 31.88/0.9373
# Scale: 4
# PSNR/SSIM: 28.41/0.8769
# Scale: 8
# PSNR/SSIM: 21.72/0.6257
# Scale: 16
# PSNR/SSIM: 19.36/0.5439
#
# img_008.png
# Scale: 2
# PSNR/SSIM: 26.06/0.8891
# Scale: 3
# PSNR/SSIM: 23.99/0.7829
# Scale: 4
# PSNR/SSIM: 20.97/0.6189
# Scale: 8
# PSNR/SSIM: 18.32/0.3237
# Scale: 16
# PSNR/SSIM: 17.19/0.2528
#
# img_087.png
# Scale: 2
# PSNR/SSIM: 33.72/0.9652
# Scale: 3
# PSNR/SSIM: 30.34/0.9254
# Scale: 4
# PSNR/SSIM: 26.16/0.8494
# Scale: 8
# PSNR/SSIM: 20.54/0.6368
# Scale: 16
# PSNR/SSIM: 18.40/0.5773
#
# img_096.png
# Scale: 2
# PSNR/SSIM: 31.58/0.9662
# Scale: 3
# PSNR/SSIM: 28.17/0.9170
# Scale: 4
# PSNR/SSIM: 23.30/0.8072
# Scale: 8
# PSNR/SSIM: 19.28/0.5560
# Scale: 16
# PSNR/SSIM: 18.52/0.5145
#
# img_023.png
# Scale: 2
# PSNR/SSIM: 37.05/0.9787
# Scale: 3
# PSNR/SSIM: 33.29/0.9523
# Scale: 4
# PSNR/SSIM: 29.56/0.8988
# Scale: 8
# PSNR/SSIM: 22.26/0.6168
# Scale: 16
# PSNR/SSIM: 20.26/0.5224
#
# img_049.png
# Scale: 2
# PSNR/SSIM: 27.52/0.8953
# Scale: 3
# PSNR/SSIM: 25.45/0.8256
# Scale: 4
# PSNR/SSIM: 22.52/0.7090
# Scale: 8
# PSNR/SSIM: 17.97/0.4075
# Scale: 16
# PSNR/SSIM: 15.87/0.3025
#
# img_032.png
# Scale: 2
# PSNR/SSIM: 34.38/0.9529
# Scale: 3
# PSNR/SSIM: 32.05/0.9140
# Scale: 4
# PSNR/SSIM: 28.22/0.8284
# Scale: 8
# PSNR/SSIM: 24.22/0.6760
# Scale: 16
# PSNR/SSIM: 23.09/0.6566
#
# img_034.png
# Scale: 2
# PSNR/SSIM: 26.15/0.7941
# Scale: 3
# PSNR/SSIM: 25.25/0.6998
# Scale: 4
# PSNR/SSIM: 22.71/0.5675
# Scale: 8
# PSNR/SSIM: 19.59/0.3542
# Scale: 16
# PSNR/SSIM: 18.11/0.3092
#
# img_051.png
# Scale: 2
# PSNR/SSIM: 32.99/0.9550
# Scale: 3
# PSNR/SSIM: 29.93/0.9079
# Scale: 4
# PSNR/SSIM: 26.72/0.8266
# Scale: 8
# PSNR/SSIM: 22.23/0.5910
# Scale: 16
# PSNR/SSIM: 20.55/0.5224
#
# img_093.png
# Scale: 2
# PSNR/SSIM: 36.83/0.9756
# Scale: 3
# PSNR/SSIM: 32.05/0.9549
# Scale: 4
# PSNR/SSIM: 27.41/0.9111
# Scale: 8
# PSNR/SSIM: 19.58/0.6079
# Scale: 16
# PSNR/SSIM: 16.61/0.5006
#
# img_056.png
# Scale: 2
# PSNR/SSIM: 29.85/0.9298
# Scale: 3
# PSNR/SSIM: 26.97/0.8560
# Scale: 4
# PSNR/SSIM: 24.27/0.7519
# Scale: 8
# PSNR/SSIM: 19.63/0.4443
# Scale: 16
# PSNR/SSIM: 17.41/0.3450
#
# img_091.png
# Scale: 2
# PSNR/SSIM: 28.26/0.8816
# Scale: 3
# PSNR/SSIM: 26.14/0.7809
# Scale: 4
# PSNR/SSIM: 23.44/0.6349
# Scale: 8
# PSNR/SSIM: 19.99/0.3431
# Scale: 16
# PSNR/SSIM: 18.65/0.2975
#
# img_035.png
# Scale: 2
# PSNR/SSIM: 32.18/0.9497
# Scale: 3
# PSNR/SSIM: 31.06/0.9278
# Scale: 4
# PSNR/SSIM: 27.21/0.8482
# Scale: 8
# PSNR/SSIM: 20.97/0.5746
# Scale: 16
# PSNR/SSIM: 18.88/0.5008
#
# img_041.png
# Scale: 2
# PSNR/SSIM: 32.88/0.9650
# Scale: 3
# PSNR/SSIM: 28.56/0.9236
# Scale: 4
# PSNR/SSIM: 24.31/0.8273
# Scale: 8
# PSNR/SSIM: 18.04/0.4701
# Scale: 16
# PSNR/SSIM: 15.41/0.3557
#
# img_052.png
# Scale: 2
# PSNR/SSIM: 34.26/0.9701
# Scale: 3
# PSNR/SSIM: 32.27/0.9494
# Scale: 4
# PSNR/SSIM: 28.14/0.8934
# Scale: 8
# PSNR/SSIM: 20.91/0.5922
# Scale: 16
# PSNR/SSIM: 18.76/0.5359
#
# img_070.png
# Scale: 2
# PSNR/SSIM: 24.57/0.7885
# Scale: 3
# PSNR/SSIM: 23.40/0.6750
# Scale: 4
# PSNR/SSIM: 21.99/0.5803
# Scale: 8
# PSNR/SSIM: 20.45/0.4390
# Scale: 16
# PSNR/SSIM: 19.60/0.4075
#
# img_076.png
# Scale: 2
# PSNR/SSIM: 30.07/0.9471
# Scale: 3
# PSNR/SSIM: 25.72/0.8494
# Scale: 4
# PSNR/SSIM: 22.20/0.6944
# Scale: 8
# PSNR/SSIM: 20.10/0.4985
# Scale: 16
# PSNR/SSIM: 18.72/0.4404
#
# img_021.png
# Scale: 2
# PSNR/SSIM: 34.04/0.9163
# Scale: 3
# PSNR/SSIM: 31.31/0.8441
# Scale: 4
# PSNR/SSIM: 29.18/0.7734
# Scale: 8
# PSNR/SSIM: 24.65/0.5992
# Scale: 16
# PSNR/SSIM: 22.40/0.5454
#
# img_048.png
# Scale: 2
# PSNR/SSIM: 25.78/0.9505
# Scale: 3
# PSNR/SSIM: 22.06/0.8726
# Scale: 4
# PSNR/SSIM: 19.29/0.7703
# Scale: 8
# PSNR/SSIM: 16.71/0.5589
# Scale: 16
# PSNR/SSIM: 15.95/0.5218
#
# img_077.png
# Scale: 2
# PSNR/SSIM: 25.50/0.8492
# Scale: 3
# PSNR/SSIM: 24.67/0.7705
# Scale: 4
# PSNR/SSIM: 22.54/0.6560
# Scale: 8
# PSNR/SSIM: 20.73/0.4924
# Scale: 16
# PSNR/SSIM: 19.91/0.4478
#
# img_082.png
# Scale: 2
# PSNR/SSIM: 38.66/0.9753
# Scale: 3
# PSNR/SSIM: 35.73/0.9651
# Scale: 4
# PSNR/SSIM: 31.94/0.9360
# Scale: 8
# PSNR/SSIM: 23.78/0.7716
# Scale: 16
# PSNR/SSIM: 20.29/0.6744
#
# img_072.png
# Scale: 2
# PSNR/SSIM: 25.29/0.9455
# Scale: 3
# PSNR/SSIM: 23.47/0.9009
# Scale: 4
# PSNR/SSIM: 19.29/0.7751
# Scale: 8
# PSNR/SSIM: 14.02/0.2996
# Scale: 16
# PSNR/SSIM: 12.35/0.2165
#
# img_029.png
# Scale: 2
# PSNR/SSIM: 31.94/0.9545
# Scale: 3
# PSNR/SSIM: 29.68/0.9159
# Scale: 4
# PSNR/SSIM: 25.79/0.8342
# Scale: 8
# PSNR/SSIM: 21.03/0.6090
# Scale: 16
# PSNR/SSIM: 19.26/0.5607
#
# img_095.png
# Scale: 2
# PSNR/SSIM: 23.49/0.7473
# Scale: 3
# PSNR/SSIM: 21.41/0.5665
# Scale: 4
# PSNR/SSIM: 19.73/0.3975
# Scale: 8
# PSNR/SSIM: 17.67/0.1624
# Scale: 16
# PSNR/SSIM: 17.08/0.1433
#
# img_061.png
# Scale: 2
# PSNR/SSIM: 29.19/0.9156
# Scale: 3
# PSNR/SSIM: 26.75/0.8312
# Scale: 4
# PSNR/SSIM: 24.27/0.7252
# Scale: 8
# PSNR/SSIM: 20.70/0.4689
# Scale: 16
# PSNR/SSIM: 19.35/0.4087
#
# img_016.png
# Scale: 2
# PSNR/SSIM: 36.39/0.9614
# Scale: 3
# PSNR/SSIM: 33.58/0.9491
# Scale: 4
# PSNR/SSIM: 29.53/0.9078
# Scale: 8
# PSNR/SSIM: 22.51/0.7416
# Scale: 16
# PSNR/SSIM: 19.19/0.6768
#
# img_068.png
# Scale: 2
# PSNR/SSIM: 37.86/0.9746
# Scale: 3
# PSNR/SSIM: 34.19/0.9474
# Scale: 4
# PSNR/SSIM: 29.99/0.8727
# Scale: 8
# PSNR/SSIM: 24.20/0.6066
# Scale: 16
# PSNR/SSIM: 21.91/0.5385
#
# img_059.png
# Scale: 2
# PSNR/SSIM: 26.37/0.8960
# Scale: 3
# PSNR/SSIM: 24.81/0.8366
# Scale: 4
# PSNR/SSIM: 21.41/0.7312
# Scale: 8
# PSNR/SSIM: 19.69/0.6032
# Scale: 16
# PSNR/SSIM: 19.80/0.5909
#
# img_088.png
# Scale: 2
# PSNR/SSIM: 23.69/0.8262
# Scale: 3
# PSNR/SSIM: 21.27/0.6750
# Scale: 4
# PSNR/SSIM: 19.44/0.5216
# Scale: 8
# PSNR/SSIM: 16.99/0.2476
# Scale: 16
# PSNR/SSIM: 15.87/0.1882
#
# img_098.png
# Scale: 2
# PSNR/SSIM: 23.91/0.7908
# Scale: 3
# PSNR/SSIM: 22.88/0.6656
# Scale: 4
# PSNR/SSIM: 20.42/0.4964
# Scale: 8
# PSNR/SSIM: 18.50/0.2574
# Scale: 16
# PSNR/SSIM: 17.93/0.2205
#
# img_007.png
# Scale: 2
# PSNR/SSIM: 35.48/0.9626
# Scale: 3
# PSNR/SSIM: 31.91/0.9168
# Scale: 4
# PSNR/SSIM: 28.83/0.8440
# Scale: 8
# PSNR/SSIM: 22.16/0.5757
# Scale: 16
# PSNR/SSIM: 19.15/0.4648
#
# img_025.png
# Scale: 2
# PSNR/SSIM: 36.80/0.9580
# Scale: 3
# PSNR/SSIM: 34.76/0.9434
# Scale: 4
# PSNR/SSIM: 31.23/0.8921
# Scale: 8
# PSNR/SSIM: 22.89/0.6664
# Scale: 16
# PSNR/SSIM: 19.80/0.5796
#
# img_043.png
# Scale: 2
# PSNR/SSIM: 36.37/0.9721
# Scale: 3
# PSNR/SSIM: 33.55/0.9537
# Scale: 4
# PSNR/SSIM: 30.08/0.9234
# Scale: 8
# PSNR/SSIM: 18.42/0.6113
# Scale: 16
# PSNR/SSIM: 14.85/0.4729
#
# img_089.png
# Scale: 2
# PSNR/SSIM: 31.22/0.9020
# Scale: 3
# PSNR/SSIM: 28.43/0.8070
# Scale: 4
# PSNR/SSIM: 26.51/0.7011
# Scale: 8
# PSNR/SSIM: 23.40/0.4876
# Scale: 16
# PSNR/SSIM: 21.51/0.4263
#
# img_015.png
# Scale: 2
# PSNR/SSIM: 29.83/0.8487
# Scale: 3
# PSNR/SSIM: 28.86/0.8267
# Scale: 4
# PSNR/SSIM: 25.46/0.7191
# Scale: 8
# PSNR/SSIM: 21.23/0.5099
# Scale: 16
# PSNR/SSIM: 18.84/0.4363
#
# img_092.png
# Scale: 2
# PSNR/SSIM: 22.34/0.8196
# Scale: 3
# PSNR/SSIM: 21.79/0.7629
# Scale: 4
# PSNR/SSIM: 18.28/0.6092
# Scale: 8
# PSNR/SSIM: 15.96/0.3573
# Scale: 16
# PSNR/SSIM: 15.14/0.3144
#
# img_057.png
# Scale: 2
# PSNR/SSIM: 37.23/0.9713
# Scale: 3
# PSNR/SSIM: 34.26/0.9444
# Scale: 4
# PSNR/SSIM: 29.91/0.8769
# Scale: 8
# PSNR/SSIM: 23.14/0.6919
# Scale: 16
# PSNR/SSIM: 19.98/0.6183
#
# img_018.png
# Scale: 2
# PSNR/SSIM: 29.68/0.8819
# Scale: 3
# PSNR/SSIM: 28.42/0.8046
# Scale: 4
# PSNR/SSIM: 26.02/0.6929
# Scale: 8
# PSNR/SSIM: 22.40/0.4534
# Scale: 16
# PSNR/SSIM: 20.32/0.3692
#
# img_033.png
# Scale: 2
# PSNR/SSIM: 31.59/0.9229
# Scale: 3
# PSNR/SSIM: 29.60/0.8682
# Scale: 4
# PSNR/SSIM: 26.52/0.7670
# Scale: 8
# PSNR/SSIM: 22.50/0.5937
# Scale: 16
# PSNR/SSIM: 21.28/0.5785
#
# img_036.png
# Scale: 2
# PSNR/SSIM: 34.67/0.9621
# Scale: 3
# PSNR/SSIM: 32.02/0.9391
# Scale: 4
# PSNR/SSIM: 28.67/0.8830
# Scale: 8
# PSNR/SSIM: 22.46/0.6570
# Scale: 16
# PSNR/SSIM: 20.12/0.5855
#
# img_074.png
# Scale: 2
# PSNR/SSIM: 28.41/0.9075
# Scale: 3
# PSNR/SSIM: 26.45/0.8112
# Scale: 4
# PSNR/SSIM: 23.25/0.6569
# Scale: 8
# PSNR/SSIM: 20.97/0.4686
# Scale: 16
# PSNR/SSIM: 20.48/0.4523
#
# img_038.png
# Scale: 2
# PSNR/SSIM: 31.63/0.8730
# Scale: 3
# PSNR/SSIM: 28.72/0.7687
# Scale: 4
# PSNR/SSIM: 26.26/0.6407
# Scale: 8
# PSNR/SSIM: 23.22/0.4248
# Scale: 16
# PSNR/SSIM: 22.28/0.4019
#
# img_022.png
# Scale: 2
# PSNR/SSIM: 29.25/0.8891
# Scale: 3
# PSNR/SSIM: 28.40/0.8363
# Scale: 4
# PSNR/SSIM: 25.86/0.7457
# Scale: 8
# PSNR/SSIM: 23.59/0.6179
# Scale: 16
# PSNR/SSIM: 22.53/0.5894
#
# img_067.png
# Scale: 2
# PSNR/SSIM: 23.84/0.9535
# Scale: 3
# PSNR/SSIM: 21.44/0.9052
# Scale: 4
# PSNR/SSIM: 18.34/0.8269
# Scale: 8
# PSNR/SSIM: 14.73/0.5246
# Scale: 16
# PSNR/SSIM: 13.50/0.4332
#
# img_069.png
# Scale: 2
# PSNR/SSIM: 29.48/0.9195
# Scale: 3
# PSNR/SSIM: 27.00/0.8404
# Scale: 4
# PSNR/SSIM: 24.47/0.7374
# Scale: 8
# PSNR/SSIM: 21.09/0.5004
# Scale: 16
# PSNR/SSIM: 19.77/0.4514
#
# img_063.png
# Scale: 2
# PSNR/SSIM: 25.51/0.7413
# Scale: 3
# PSNR/SSIM: 23.53/0.7297
# Scale: 4
# PSNR/SSIM: 21.57/0.5950
# Scale: 8
# PSNR/SSIM: 16.15/0.3245
# Scale: 16
# PSNR/SSIM: 15.29/0.3288
#
# img_046.png
# Scale: 2
# PSNR/SSIM: 27.27/0.9092
# Scale: 3
# PSNR/SSIM: 25.60/0.8217
# Scale: 4
# PSNR/SSIM: 23.43/0.7393
# Scale: 8
# PSNR/SSIM: 22.12/0.6112
# Scale: 16
# PSNR/SSIM: 21.17/0.5781
#
# img_017.png
# Scale: 2
# PSNR/SSIM: 30.92/0.9483
# Scale: 3
# PSNR/SSIM: 28.31/0.8936
# Scale: 4
# PSNR/SSIM: 25.08/0.7986
# Scale: 8
# PSNR/SSIM: 21.35/0.5888
# Scale: 16
# PSNR/SSIM: 19.35/0.5172
#
# img_005.png
# Scale: 2
# PSNR/SSIM: 35.09/0.9847
# Scale: 3
# PSNR/SSIM: 30.08/0.9664
# Scale: 4
# PSNR/SSIM: 26.79/0.9337
# Scale: 8
# PSNR/SSIM: 19.94/0.6928
# Scale: 16
# PSNR/SSIM: 17.82/0.6216
#
# img_060.png
# Scale: 2
# PSNR/SSIM: 25.50/0.7892
# Scale: 3
# PSNR/SSIM: 24.17/0.6786
# Scale: 4
# PSNR/SSIM: 22.09/0.5323
# Scale: 8
# PSNR/SSIM: 19.70/0.3152
# Scale: 16
# PSNR/SSIM: 18.68/0.2672
#
# img_014.png
# Scale: 2
# PSNR/SSIM: 25.36/0.8614
# Scale: 3
# PSNR/SSIM: 24.90/0.8005
# Scale: 4
# PSNR/SSIM: 22.26/0.6709
# Scale: 8
# PSNR/SSIM: 20.25/0.4926
# Scale: 16
# PSNR/SSIM: 19.29/0.4539
#
# img_031.png
# Scale: 2
# PSNR/SSIM: 27.96/0.9230
# Scale: 3
# PSNR/SSIM: 26.26/0.8645
# Scale: 4
# PSNR/SSIM: 23.80/0.7679
# Scale: 8
# PSNR/SSIM: 20.91/0.5593
# Scale: 16
# PSNR/SSIM: 19.87/0.5109
#
# img_055.png
# Scale: 2
# PSNR/SSIM: 37.39/0.9779
# Scale: 3
# PSNR/SSIM: 34.42/0.9619
# Scale: 4
# PSNR/SSIM: 31.39/0.9334
# Scale: 8
# PSNR/SSIM: 21.30/0.6182
# Scale: 16
# PSNR/SSIM: 19.67/0.5903
#
# img_099.png
# Scale: 2
# PSNR/SSIM: 31.27/0.9354
# Scale: 3
# PSNR/SSIM: 27.85/0.8557
# Scale: 4
# PSNR/SSIM: 24.19/0.7134
# Scale: 8
# PSNR/SSIM: 20.92/0.4710
# Scale: 16
# PSNR/SSIM: 19.41/0.4080
#
# img_053.png
# Scale: 2
# PSNR/SSIM: 26.94/0.9016
# Scale: 3
# PSNR/SSIM: 25.00/0.8324
# Scale: 4
# PSNR/SSIM: 21.76/0.6948
# Scale: 8
# PSNR/SSIM: 17.90/0.4110
# Scale: 16
# PSNR/SSIM: 15.92/0.3105
#
# img_030.png
# Scale: 2
# PSNR/SSIM: 29.93/0.9429
# Scale: 3
# PSNR/SSIM: 27.00/0.8795
# Scale: 4
# PSNR/SSIM: 23.56/0.7581
# Scale: 8
# PSNR/SSIM: 19.17/0.4294
# Scale: 16
# PSNR/SSIM: 17.17/0.3486
#
# img_094.png
# Scale: 2
# PSNR/SSIM: 30.93/0.9069
# Scale: 3
# PSNR/SSIM: 29.38/0.8487
# Scale: 4
# PSNR/SSIM: 26.85/0.7712
# Scale: 8
